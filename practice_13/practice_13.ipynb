# %% [markdown]
# # 実践13
# * data-analysis-basic-kadaiリポジトリへpractice_13フォルダを作成し以下格納する。

# %% [markdown]
# ## 実践13-1
# * K-Meansクラスタリングによる品種の分類
#     * irisデータセットをロードする
#     * 説明変数(4つの特徴量)を抽出する
#     * K-Means法によりクラスタリングを行う
#     * エルボー法で最適なクラスタ数を決定する
#     * クラスタリング結果と実際の品種ラベルを比較し、正解率を計算する(教師なし学習なので通常は実施しないが、参考のために実施する)

# %%
# データセットの取得
import pandas as pd
from sklearn.datasets import load_iris
iris = load_iris()
print(iris.DESCR)
# Out:
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 150 (50 in each of three classes)
#     :Number of Attributes: 4 numeric, predictive attributes and the class
#     :Attribute Information:
#         - sepal length in cm
#         - sepal width in cm
#         - petal length in cm
#         - petal width in cm
#         - class:
#                 - Iris-Setosa
#                 - Iris-Versicolour
#                 - Iris-Virginica
#
#     :Summary Statistics:
#
#     ============== ==== ==== ======= ===== ====================
#                     Min  Max   Mean    SD   Class Correlation
#     ============== ==== ==== ======= ===== ====================
#     sepal length:   4.3  7.9   5.84   0.83    0.7826
#     sepal width:    2.0  4.4   3.05   0.43   -0.4194
#     petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)
#     petal width:    0.1  2.5   1.20   0.76    0.9565  (high!)
# ...

# %%
# 説明変数と目的変数の取得
X = iris.data
y = iris.target

# データ内容の確認
df = pd.DataFrame(X, columns=iris.feature_names)
df['target'] = y
display(df.head())
display(df.info())
display(df.shape)
display(df.describe())
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   target             150 non-null    int64
# ...

# %%
# 説明変数の標準化
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X)
X_scaled = scaler.transform(X)
df_scaled = pd.DataFrame(X_scaled, columns=iris.feature_names)
df_scaled.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count       1.500000e+02      1.500000e+02       1.500000e+02
# mean       -1.468455e-15     -1.823726e-15      -1.610564e-15
# std         1.003350e+00      1.003350e+00       1.003350e+00
# min        -1.870024e+00     -2.433947e+00      -1.567576e+00
# 25%        -9.006812e-01     -5.923730e-01      -1.226552e+00
# 50%        -5.250608e-02     -1.319795e-01       3.364776e-01
# 75%         6.745011e-01      5.586108e-01       7.627583e-01
# max         2.492019e+00      3.090775e+00       1.785832e+00
#
#        petal width (cm)
# count      1.500000e+02
# mean      -9.473903e-16
# std        1.003350e+00
# min       -1.447076e+00
# 25%       -1.183812e+00
# 50%        1.325097e-01
# 75%        7.906707e-01
# max        1.712096e+00

# %%
# エルボー法でクラスタ数を検討する
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
# 誤差指標の格納リスト
distortions = []
cluster_ranges = range(1, 11)
for cluster in cluster_ranges:
    # k-meansのモデル定義
    kmeans = KMeans(n_clusters=cluster, random_state=0)
    # クラスタリングの実行
    kmeans.fit(X_scaled)
    # 誤差指標をリストに追加
    distortions.append(kmeans.inertia_)

# エルボー法の結果を可視化
plt.figure(figsize=(6, 6))
plt.plot(cluster_ranges, distortions)
plt.xlabel('number of clusters', fontsize=14)
plt.ylabel('distance', fontsize=14)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
# クラスター数3でk-meansを実行
kmeans = KMeans(n_clusters=3, random_state=0)
kmeans.fit(X_scaled)
df['クラスター'] = kmeans.labels_
df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target  クラスター
# 0       0      1
# 1       0      1
# 2       0      1
# 3       0      1
# 4       0      1

# %%
# targetとクラスターを確認
pd.crosstab(index=df['target'], columns=df['クラスター'])
# Out:
# クラスター    0   1   2
# target
# 0        0  50   0
# 1       39   0  11
# 2       14   0  36

# %%
# 正解率を算出する
from sklearn.metrics import accuracy_score
df_accuracy = df.replace({'クラスター': {0: 1, 1: 0}})
display(pd.crosstab(index=df_accuracy['target'], columns=df_accuracy['クラスター']))
accuracy = accuracy_score(df_accuracy['target'], df_accuracy['クラスター'])
print(f"正解率{accuracy:.3f}")
# Out:
# クラスター    0   1   2
# target
# 0       50   0   0
# 1        0  39  11
# 2        0  14  36
# 正解率0.833

# %% [markdown]
# ## 実践13-2
# * K-Means以外のクラスタリング手法による品種の分類
#     * 13-1をK-Means以外の手法で実施する(階層的クラスタリング・DBSCAN・etc)
#     * クラスタリング結果と実際の品種ラベルを比較し、正解率を計算する

# %%
# データセットの取得
import pandas as pd
from sklearn.datasets import load_iris
iris = load_iris()
print(iris.DESCR)
# Out:
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 150 (50 in each of three classes)
#     :Number of Attributes: 4 numeric, predictive attributes and the class
#     :Attribute Information:
#         - sepal length in cm
#         - sepal width in cm
#         - petal length in cm
#         - petal width in cm
#         - class:
#                 - Iris-Setosa
#                 - Iris-Versicolour
#                 - Iris-Virginica
#
#     :Summary Statistics:
#
#     ============== ==== ==== ======= ===== ====================
#                     Min  Max   Mean    SD   Class Correlation
#     ============== ==== ==== ======= ===== ====================
#     sepal length:   4.3  7.9   5.84   0.83    0.7826
#     sepal width:    2.0  4.4   3.05   0.43   -0.4194
#     petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)
#     petal width:    0.1  2.5   1.20   0.76    0.9565  (high!)
# ...

# %%
# 説明変数と目的変数の抽出
X = iris.data
y = iris.target

# データ内容の確認
df = pd.DataFrame(X, columns=iris.feature_names)
df['target'] = y
display(df.head())
display(df.info())
display(df.shape)
display(df.describe())
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   target             150 non-null    int64
# ...

# %%
# 説明変数の標準化
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X)
X_scaled = scaler.transform(X)
df_scaled = pd.DataFrame(X_scaled, columns=iris.feature_names)
df_scaled.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count       1.500000e+02      1.500000e+02       1.500000e+02
# mean       -1.468455e-15     -1.823726e-15      -1.610564e-15
# std         1.003350e+00      1.003350e+00       1.003350e+00
# min        -1.870024e+00     -2.433947e+00      -1.567576e+00
# 25%        -9.006812e-01     -5.923730e-01      -1.226552e+00
# 50%        -5.250608e-02     -1.319795e-01       3.364776e-01
# 75%         6.745011e-01      5.586108e-01       7.627583e-01
# max         2.492019e+00      3.090775e+00       1.785832e+00
#
#        petal width (cm)
# count      1.500000e+02
# mean      -9.473903e-16
# std        1.003350e+00
# min       -1.447076e+00
# 25%       -1.183812e+00
# 50%        1.325097e-01
# 75%        7.906707e-01
# max        1.712096e+00

# %%
pip install japanize-matplotlib

# %%
# DBSCANでクラスタリング
import japanize_matplotlib
import seaborn as sns
from sklearn.cluster import DBSCAN
import matplotlib.pyplot as plt
db = DBSCAN()
db.fit(X_scaled)

df['クラスター'] = db.labels_
df.head()

fig, axes = plt.subplots(1, 2, figsize=(10, 5))
sns.scatterplot(x='sepal width (cm)', y='petal width (cm)', hue='target', data=df, ax=axes[0])
sns.scatterplot(x='sepal width (cm)', y='petal width (cm)', hue='クラスター', data=df, ax=axes[1])
plt.show()

# targetとクラスターを確認
pd.crosstab(index=df['target'], columns=df['クラスター'])
# Out:
# クラスター   -1   0   1
# target
# 0        5  45   0
# 1       11   0  39
# 2       18   0  32

# %%
# 正解率を算出する
from sklearn.metrics import accuracy_score
df_accuracy = df.replace({'クラスター': {-1: 2}})
display(pd.crosstab(index=df_accuracy['target'], columns=df_accuracy['クラスター']))
accuracy = accuracy_score(df['target'], df['クラスター'])
print(f"正解率{accuracy:.3f}")
# Out:
# クラスター    0   1   2
# target
# 0       45   0   5
# 1        0  39  11
# 2        0  32  18
# 正解率0.560

# %% [markdown]
# ## 実践13-3
#
#
#
# ```
# from sklearn.datasets import load_wine
# wine = load_wine()
# X, y = wine.data, wine.target
# ```
#
# 上記のデータを使ってクラスタリングを実施してください。
# 特徴量のスケーリング等に注意して実施してください。
# 本データは実際には正解データ(ラベル数)が付与されています。
# クラスタリングである程度分類できるか正解率を計算してください。

# %%
# データの取得
from sklearn.datasets import load_wine
wine = load_wine()
X, y = wine.data, wine.target
print(wine.DESCR)
# Out:
# .. _wine_dataset:
#
# Wine recognition dataset
# ------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 178
#     :Number of Attributes: 13 numeric, predictive attributes and the class
#     :Attribute Information:
#  		- Alcohol
#  		- Malic acid
#  		- Ash
# 		- Alcalinity of ash
#  		- Magnesium
# 		- Total phenols
#  		- Flavanoids
#  		- Nonflavanoid phenols
#  		- Proanthocyanins
# 		- Color intensity
#  		- Hue
#  		- OD280/OD315 of diluted wines
#  		- Proline
#
#     - class:
#             - class_0
#             - class_1
#             - class_2
#
#     :Summary Statistics:
#
#     ============================= ==== ===== ======= =====
#                                    Min   Max   Mean     SD
#     ============================= ==== ===== ======= =====
#     Alcohol:                      11.0  14.8    13.0   0.8
#     Malic Acid:                   0.74  5.80    2.34  1.12
#     Ash:                          1.36  3.23    2.36  0.27
# ...

# %%
# データの確認
import pandas as pd
df = pd.DataFrame(X, columns=wine.feature_names)
df['target'] = y
display(df.head())
display(df.info())
display(df.shape)
display(df.describe())
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline  target
# ...

# %%
# 説明変数の標準化
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X)
X_scaled = scaler.transform(X)
df_scaled = pd.DataFrame(X_scaled, columns=wine.feature_names)
display(df_scaled.describe())
# Out:
#             alcohol    malic_acid           ash  alcalinity_of_ash  \
# count  1.780000e+02  1.780000e+02  1.780000e+02       1.780000e+02
# mean   7.943708e-15  3.592632e-16 -4.066660e-15      -7.983626e-17
# std    1.002821e+00  1.002821e+00  1.002821e+00       1.002821e+00
# min   -2.434235e+00 -1.432983e+00 -3.679162e+00      -2.671018e+00
# 25%   -7.882448e-01 -6.587486e-01 -5.721225e-01      -6.891372e-01
# 50%    6.099988e-02 -4.231120e-01 -2.382132e-02       1.518295e-03
# 75%    8.361286e-01  6.697929e-01  6.981085e-01       6.020883e-01
# max    2.259772e+00  3.109192e+00  3.156325e+00       3.154511e+00
#
#           magnesium  total_phenols    flavanoids  nonflavanoid_phenols  \
# count  1.780000e+02   1.780000e+02  1.780000e+02          1.780000e+02
# mean  -7.983626e-17  -3.991813e-17  9.979533e-16         -5.588538e-16
# std    1.002821e+00   1.002821e+00  1.002821e+00          1.002821e+00
# min   -2.088255e+00  -2.107246e+00 -1.695971e+00         -1.868234e+00
# ...

# %%
# エルボー法でクラスター数を検討する
# 誤差指標格納リスト
from sklearn.cluster import KMeans
distortions = []
cluster_ranges = range(1, 11)
for cluster in cluster_ranges:
    # k-meansのモデル定義
    kmeans = KMeans(n_clusters=cluster, random_state=0)
    kmeans.fit(X_scaled)
    distortions.append(kmeans.inertia_)

# 結果を可視化
plt.figure(figsize=(6, 6))
plt.plot(cluster_ranges, distortions)
plt.xlabel('number of clusters', fontsize=14)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
# クラスター数3でk-meansを実行する
kmeans = KMeans(n_clusters=3, random_state=0)
kmeans.fit(X_scaled)
df['クラスター'] = kmeans.labels_
display(df.head())
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# ...

# %%
# targetとクラスターを確認
pd.crosstab(index=df['target'], columns=df['クラスター'])
# Out:
# クラスター    0   1   2
# target
# 0        0   0  59
# 1        3  66   2
# 2       48   0   0

# %%
# 正解率を計算する
from sklearn.metrics import accuracy_score
df_accuracy = df.replace({'クラスター': {0 : 2, 2 : 0}})
display(pd.crosstab(index=df_accuracy['target'], columns=df_accuracy['クラスター']))
accuracy = accuracy_score(df_accuracy['target'], df_accuracy['クラスター'])
print(f"正解率{accuracy:.3f}")
# Out:
# クラスター    0   1   2
# target
# 0       59   0   0
# 1        2  66   3
# 2        0   0  48
# 正解率0.972
